# %% [markdown]
# Importación de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# Lectura de datos

# %%
df = pd.read_csv("wordCloud.csv")

# %%
df

# %%
df.isna().sum()
# Out:
# Categoria    0
# dtype: int64

# %%
text = " ".join(de.split()[0] for de in df.Categoria)

# %%
text
# Out:
# 'Drama Crimen Acción Suspenso Drama Comedia Documental Ganster Ganster Ciencia Suspenso Drama Comedia Acción Comedia Drama Suspenso Terror Internacional Comedia Anime Documental Drama Internacional Drama Suspenso Coming Suspenso'

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# %% [markdown]
# Plot de wordcloud

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Reference:
# https://www.analyticsvidhya.com/blog/2021/05/how-to-build-word-cloud-in-python/
